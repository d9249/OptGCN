# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
# user_emb = torch.load('./embedding/base/SelfCF_MovieLens-1m/best_user_emb.pt', map_location=torch.device('cpu'))
# item_emb = torch.load('./embedding/base/SelfCF_MovieLens-1m/best_item_emb.pt', map_location=torch.device('cpu'))

best_p_u = torch.load('./embedding/base/SelfCF_MovieLens-1m/best_p_u.pt', map_location=torch.device('cpu'))
best_u = torch.load('./embedding/base/SelfCF_MovieLens-1m/best_u.pt', map_location=torch.device('cpu'))
best_p_i = torch.load('./embedding/base/SelfCF_MovieLens-1m/best_p_i.pt', map_location=torch.device('cpu'))
best_i = torch.load('./embedding/base/SelfCF_MovieLens-1m/best_i.pt', map_location=torch.device('cpu'))

# Creating combined embeddings
user_emb = best_p_u + best_u
item_emb = best_p_i + best_i

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("SelfCF")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/SelfCF_MovieLens-1m/SelfCF.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/base/MF_MovieLens-1m/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/base/MF_MovieLens-1m/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("MF")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/MF_MovieLens-1m/MF.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/base/DirectAU_MovieLens-1m/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/base/DirectAU_MovieLens-1m/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("DirectAU")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/DirectAU_MovieLens-1m/DirectAU.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/base/XSimGCL_MovieLens-1m/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/base/XSimGCL_MovieLens-1m/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("XSimGCL")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/XSimGCL_MovieLens-1m/XSimGCL.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/base/SGL_MovieLens-1m/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/base/SGL_MovieLens-1m/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("SGL")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/SGL_MovieLens-1m/SGL.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/base/MixGCF_MovieLens-1m/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/base/MixGCF_MovieLens-1m/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("MixGCF")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/MixGCF_MovieLens-1m/MixGCF.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
# user_emb = torch.load('./embedding/base/SelfCF_MovieLens-1m/best_user_emb.pt', map_location=torch.device('cpu'))
# item_emb = torch.load('./embedding/base/SelfCF_MovieLens-1m/best_item_emb.pt', map_location=torch.device('cpu'))

best_p_u = torch.load('./embedding/base/BUIR_MovieLens-1m/best_p_u.pt', map_location=torch.device('cpu'))
best_u = torch.load('./embedding/base/BUIR_MovieLens-1m/best_u.pt', map_location=torch.device('cpu'))
best_p_i = torch.load('./embedding/base/BUIR_MovieLens-1m/best_p_i.pt', map_location=torch.device('cpu'))
best_i = torch.load('./embedding/base/BUIR_MovieLens-1m/best_i.pt', map_location=torch.device('cpu'))

# Creating combined embeddings
user_emb = best_p_u + best_u
item_emb = best_p_i + best_i

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("BUIR")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/BUIR_MovieLens-1m/BUIR.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/base/LightGCN_MovieLens-1m/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/base/LightGCN_MovieLens-1m/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("LightGCN")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/LightGCN_MovieLens-1m/LightGCN.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/base/SimGCL_MovieLens-1m/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/base/SimGCL_MovieLens-1m/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("SimGCL")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/SimGCL_MovieLens-1m/SimGCL.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/Weight/SimGCL_Weight/ml-1m/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/Weight/SimGCL_Weight/ml-1m/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("SimGCL_Weight")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/Weight/SimGCL_Weight/ml-1m/SimGCL_Weight.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/Weight/XSimGCL_Weight/ml-1m/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/Weight/XSimGCL_Weight/ml-1m/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("XSimGCL_Weight")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/Weight/XSimGCL_Weight/ml-1m/XSimGCL_Weight.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/Weight/SGL_Weight/ml-1m/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/Weight/SGL_Weight/ml-1m/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("SGL_Weight")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/Weight/SGL_Weight/ml-1m/SGL_Weight.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
# user_emb = torch.load('./embedding/base/SelfCF_MovieLens-1m/best_user_emb.pt', map_location=torch.device('cpu'))
# item_emb = torch.load('./embedding/base/SelfCF_MovieLens-1m/best_item_emb.pt', map_location=torch.device('cpu'))

best_p_u = torch.load('./embedding/Egress/BUIR_Egress/ml-1m/best_p_u.pt', map_location=torch.device('cpu'))
best_u = torch.load('./embedding/Egress/BUIR_Egress/ml-1m/best_u.pt', map_location=torch.device('cpu'))
best_p_i = torch.load('./embedding/Egress/BUIR_Egress/ml-1m/best_p_i.pt', map_location=torch.device('cpu'))
best_i = torch.load('./embedding/Egress/BUIR_Egress/ml-1m/best_i.pt', map_location=torch.device('cpu'))

# Creating combined embeddings
user_emb = best_p_u + best_u
item_emb = best_p_i + best_i

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("BUIR_Egress")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/Egress/BUIR_Egress/ml-1m/BUIR_Egress.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/Weight_Egress/MixGCF_Weight_Egress/ml-1m/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/Weight_Egress/MixGCF_Weight_Egress/ml-1m/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("MixGCF_Weight_Egress")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/Weight_Egress/MixGCF_Weight_Egress/ml-1m/MixGCF_Weight_Egress.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/ml-1m/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/ml-1m/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/NonConcat_Egress/LightGCN_NonConcat_Egress/ml-1m/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/NonConcat_Egress/LightGCN_NonConcat_Egress/ml-1m/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("LightGCN_NonConcat_Egress")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/NonConcat_Egress/LightGCN_NonConcat_Egress/ml-1m/LightGCN_NonConcat_Egress.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('c:\\Users\\admin\\Downloads\\ThinGCN\\dataset\\ml-1m\\train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('c:\\Users\\admin\\Downloads\\ThinGCN\\dataset\\ml-1m\\test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('c:\\Users\\admin\\Downloads\\ThinGCN\\embedding\\Weight_Egress\\LightGCN_Weight_Egress\\ml-1m\\best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('c:\\Users\\admin\\Downloads\\ThinGCN\\embedding\\Weight_Egress\\LightGCN_Weight_Egress\\ml-1m\\best_item_emb.pt', map_location=torch.device('cpu'))
# C:\Users\admin\Downloads\ThinGCN\embedding\Weight_Egress\LightGCN_Weight_Egress\ml-1m\best_item_emb.pt
# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("LightGCN Egress Weight")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('c:\\Users\\admin\\Downloads\\ThinGCN\\embedding\\Weight_Egress\\LightGCN_Weight_Egress\\ml-1m\\LightGCN_Weight_Egress.png')
plt.show()
