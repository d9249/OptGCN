# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('c:\\Users\\admin\\Downloads\\ThinGCN\\dataset\\FilmTrust\\train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('c:\\Users\\admin\\Downloads\\ThinGCN\\dataset\\FilmTrust\\test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('c:\\Users\\admin\\Downloads\\ThinGCN\\embedding\\base\\MF_FilmTrust\\best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('c:\\Users\\admin\\Downloads\\ThinGCN\\embedding\\base\\MF_FilmTrust\\best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("MF")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('c:\\Users\\admin\\Downloads\\ThinGCN\\embedding\\base\\MF_FilmTrust\\MF_2.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/base/DirectAU_FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/base/DirectAU_FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("DirectAU")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/DirectAU_FilmTrust/DirectAU.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
# user_emb = torch.load('./embedding/base/SelfCF_FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
# item_emb = torch.load('./embedding/base/SelfCF_FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

best_p_u = torch.load('./embedding/base/SelfCF_FilmTrust/best_p_u.pt', map_location=torch.device('cpu'))
best_u = torch.load('./embedding/base/SelfCF_FilmTrust/best_u.pt', map_location=torch.device('cpu'))
best_p_i = torch.load('./embedding/base/SelfCF_FilmTrust/best_p_i.pt', map_location=torch.device('cpu'))
best_i = torch.load('./embedding/base/SelfCF_FilmTrust/best_i.pt', map_location=torch.device('cpu'))

# Creating combined embeddings
user_emb = best_p_u + best_u
item_emb = best_p_i + best_i

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("SelfCF")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/SelfCF_FilmTrust/SelfCF.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/base/LightGCN_FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/base/LightGCN_FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("LightGCN")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/LightGCN_FilmTrust/LightGCN.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/base/SimGCL_FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/base/SimGCL_FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("SimGCL")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/SimGCL_FilmTrust/SimGCL.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/base/XSimGCL_FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/base/XSimGCL_FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("XSimGCL")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/XSimGCL_FilmTrust/XSimGCL.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/base/SGL_FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/base/SGL_FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("SGL")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/SGL_FilmTrust/SGL.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
# user_emb = torch.load('./embedding/base/SelfCF_FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
# item_emb = torch.load('./embedding/base/SelfCF_FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

best_p_u = torch.load('./embedding/base/BUIR_FilmTrust/best_p_u.pt', map_location=torch.device('cpu'))
best_u = torch.load('./embedding/base/BUIR_FilmTrust/best_u.pt', map_location=torch.device('cpu'))
best_p_i = torch.load('./embedding/base/BUIR_FilmTrust/best_p_i.pt', map_location=torch.device('cpu'))
best_i = torch.load('./embedding/base/BUIR_FilmTrust/best_i.pt', map_location=torch.device('cpu'))

# Creating combined embeddings
user_emb = best_p_u + best_u
item_emb = best_p_i + best_i

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("BUIR")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/BUIR_FilmTrust/BUIR.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/base/MixGCF_FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/base/MixGCF_FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("MixGCF")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/base/MixGCF_FilmTrust/MixGCF.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/Weight/SimGCL_Weight/FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/Weight/SimGCL_Weight/FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("SimGCL_Weight")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/Weight/SimGCL_Weight/FilmTrust/SimGCL_Weight.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/Weight/SGL_Weight/FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/Weight/SGL_Weight/FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("SGL_Weight")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/Weight/SGL_Weight/FilmTrust/SGL_Weight.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/Weight_Egress/LightGCN_Weight_Egress/FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/Weight_Egress/LightGCN_Weight_Egress/FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("LightGCN_Weight_Egress")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/Weight_Egress/LightGCN_Weight_Egress/FilmTrust/LightGCN_Weight_Egress.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
# user_emb = torch.load('./embedding/Weight_Egress/BUIR_Weight_Egress/FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
# item_emb = torch.load('./embedding/Weight_Egress/BUIR_Weight_Egress/FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

best_p_u = torch.load('./embedding/Weight_Egress/BUIR_Weight_Egress/FilmTrust/best_p_u.pt', map_location=torch.device('cpu'))
best_u = torch.load('./embedding/Weight_Egress/BUIR_Weight_Egress/FilmTrust/best_u.pt', map_location=torch.device('cpu'))
best_p_i = torch.load('./embedding/Weight_Egress/BUIR_Weight_Egress/FilmTrust/best_p_i.pt', map_location=torch.device('cpu'))
best_i = torch.load('./embedding/Weight_Egress/BUIR_Weight_Egress/FilmTrust/best_i.pt', map_location=torch.device('cpu'))

# Creating combined embeddings
user_emb = best_p_u + best_u
item_emb = best_p_i + best_i

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("BUIR_Weight_Egress")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/Weight_Egress/BUIR_Weight_Egress/FilmTrust/BUIR_Weight_Egress.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/Weight_Egress/MixGCF_Weight_Egress/FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/Weight_Egress/MixGCF_Weight_Egress/FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("MixGCF_Weight_Egress")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/Weight_Egress/MixGCF_Weight_Egress/FilmTrust/MixGCF_Weight_Egress.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random

np.random.seed(42)
random.seed(42)
torch.manual_seed(42)

# Load data
train_data = pd.read_csv('./dataset/FilmTrust/train.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
test_data = pd.read_csv('./dataset/FilmTrust/test.txt', delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
user_emb = torch.load('./embedding/Weight_Egress/XSimGCL_Weight_Egress/FilmTrust/best_user_emb.pt', map_location=torch.device('cpu'))
item_emb = torch.load('./embedding/Weight_Egress/XSimGCL_Weight_Egress/FilmTrust/best_item_emb.pt', map_location=torch.device('cpu'))

# Calculate popularity
combined_data = pd.concat([train_data, test_data])
user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

# Define thresholds for hot and cold sampling
user_hot_threshold = user_popularity['interaction'].quantile(0.95)
user_cold_threshold = user_popularity['interaction'].quantile(0.80)
item_hot_threshold = item_popularity['interaction'].quantile(0.95)
item_cold_threshold = item_popularity['interaction'].quantile(0.80)

# Sample hot and cold users/items
hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

# Ensure that user and item ids are within the valid index range
valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

hot_users = hot_users[valid_user_ids]
hot_items = hot_items[valid_item_ids]

valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

cold_users = cold_users[valid_user_ids]
cold_items = cold_items[valid_item_ids]

# Now extract embeddings
hot_user_emb = user_emb[hot_users['user_id'].values]
cold_user_emb = user_emb[cold_users['user_id'].values]
hot_item_emb = item_emb[hot_items['item_id'].values]
cold_item_emb = item_emb[cold_items['item_id'].values]



# Combine and map to 2D using t-SNE
combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
tsne = TSNE(n_components=2, random_state=42)
# user_emb_2d = tsne.fit_transform(combined_user_emb)
user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

# Create a new figure for both the scatter and KDE plots
plt.figure(figsize=(4, 6))

plt.subplot(2, 1, 1)
plt.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
plt.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
plt.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
plt.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')

plt.title("XSimGCL_Weight_Egress")
plt.xlabel("Feature")
plt.ylabel("Feature")
# plt.legend()

# Plot KDE for angles
plt.subplot(2, 1, 2, aspect=3)
sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users')  # dark gray
sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users')  # medium-dark gray
sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items')  # medium-light gray
sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items')  # light gray

# Labeling the plot
# plt.title("KDE of atan2(y, x) for Each Group")
plt.xlabel("Angle")
plt.ylabel("Density")
plt.ylim(0, 1)
# plt.legend()

plt.tight_layout()
plt.savefig('/Users/mean/Downloads/ThinGCN/embedding/Weight_Egress/XSimGCL_Weight_Egress/FilmTrust/XSimGCL_Weight_Egress.png')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE
import seaborn as sns
import random
import matplotlib.gridspec as gridspec

def plot_embeddings(train_data_path, test_data_path, user_emb_path, item_emb_path, output_path, title):
    np.random.seed(42)
    random.seed(42)
    torch.manual_seed(42)

    # Load data
    train_data = pd.read_csv(train_data_path, delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
    test_data = pd.read_csv(test_data_path, delim_whitespace=True, header=None, names=['user_id', 'item_id', 'interaction'])
    user_emb = torch.load(user_emb_path, map_location=torch.device('cpu'))
    item_emb = torch.load(item_emb_path, map_location=torch.device('cpu'))

    # Calculate popularity
    combined_data = pd.concat([train_data, test_data])
    user_popularity = combined_data.groupby('user_id')['interaction'].sum().reset_index()
    item_popularity = combined_data.groupby('item_id')['interaction'].sum().reset_index()

    # Define thresholds for hot and cold sampling
    user_hot_threshold = user_popularity['interaction'].quantile(0.95)
    user_cold_threshold = user_popularity['interaction'].quantile(0.80)
    item_hot_threshold = item_popularity['interaction'].quantile(0.95)
    item_cold_threshold = item_popularity['interaction'].quantile(0.80)

    # Sample hot and cold users/items
    hot_users = user_popularity[user_popularity['interaction'] > user_hot_threshold].sample(500, replace=True)
    cold_users = user_popularity[user_popularity['interaction'] <= user_cold_threshold].sample(500, replace=True)
    hot_items = item_popularity[item_popularity['interaction'] > item_hot_threshold].sample(500, replace=True)
    cold_items = item_popularity[item_popularity['interaction'] <= item_cold_threshold].sample(500, replace=True)

    # Ensure that user and item ids are within the valid index range
    valid_user_ids = hot_users['user_id'].apply(lambda x: x < user_emb.shape[0])
    valid_item_ids = hot_items['item_id'].apply(lambda x: x < item_emb.shape[0])

    hot_users = hot_users[valid_user_ids]
    hot_items = hot_items[valid_item_ids]

    valid_user_ids = cold_users['user_id'].apply(lambda x: x < user_emb.shape[0])
    valid_item_ids = cold_items['item_id'].apply(lambda x: x < item_emb.shape[0])

    cold_users = cold_users[valid_user_ids]
    cold_items = cold_items[valid_item_ids]

    # Now extract embeddings
    hot_user_emb = user_emb[hot_users['user_id'].values]
    cold_user_emb = user_emb[cold_users['user_id'].values]
    hot_item_emb = item_emb[hot_items['item_id'].values]
    cold_item_emb = item_emb[cold_items['item_id'].values]

    # Combine and map to 2D using t-SNE
    combined_user_emb = torch.cat([hot_user_emb, cold_user_emb])
    combined_item_emb = torch.cat([hot_item_emb, cold_item_emb])
    tsne = TSNE(n_components=2, random_state=42)
    user_emb_2d = tsne.fit_transform(combined_user_emb.detach().numpy())
    item_emb_2d = tsne.fit_transform(combined_item_emb.detach().numpy())

    angles_hot_users = np.arctan2(user_emb_2d[:500, 1], user_emb_2d[:500, 0])
    angles_cold_users = np.arctan2(user_emb_2d[500:, 1], user_emb_2d[500:, 0])
    angles_hot_items = np.arctan2(item_emb_2d[:500, 1], item_emb_2d[:500, 0])
    angles_cold_items = np.arctan2(item_emb_2d[500:, 1], item_emb_2d[500:, 0])

    # Set the size of the plots in pixels
    dpi = 100
    fig_width = 450 / dpi  # 450 pixels / 100 dpi = 4.5 inches
    fig_height = (450 + 150) / dpi  # (450 pixels + 150 pixels) / 100 dpi = 6 inches

    # Create a new figure for both the scatter and KDE plots
    fig = plt.figure(figsize=(fig_width, fig_height), dpi=dpi)
    gs = gridspec.GridSpec(2, 1, height_ratios=[2, 0.65])

    ax0 = plt.subplot(gs[0, 0])
    ax0.scatter(user_emb_2d[:500, 0], user_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Users', color='blue', marker='o')
    ax0.scatter(user_emb_2d[500:, 0], user_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Users', color='red', marker='s')
    ax0.scatter(item_emb_2d[:500, 0], item_emb_2d[:500, 1], s=5, alpha=0.5, label='Hot Items', color='green', marker='^')
    ax0.scatter(item_emb_2d[500:, 0], item_emb_2d[500:, 1], s=5, alpha=0.5, label='Cold Items', color='orange', marker='v')
    # ax0.set_title("XSimGCL_WE")
    ax0.set_title(title)
    ax0.set_xlabel("Feature")
    ax0.set_ylabel("Feature")

    ax1 = plt.subplot(gs[1, 0])
    sns.kdeplot(angles_hot_users, fill=True, color='blue', label='Hot Users', ax=ax1)
    sns.kdeplot(angles_cold_users, fill=True, color='red', label='Cold Users', ax=ax1)
    sns.kdeplot(angles_hot_items, fill=True, color='green', label='Hot Items', ax=ax1)
    sns.kdeplot(angles_cold_items, fill=True, color='orange', label='Cold Items', ax=ax1)
    ax1.set_xlabel("Angle")
    ax1.set_ylabel("Density")
    ax1.set_ylim(0, 0.5)

    plt.tight_layout()
    plt.subplots_adjust(hspace=0.2)

    # Save the plot
    plt.savefig(output_path)
    plt.show()

# Define file paths
title = 'XSimGCL_WE'
train_data_path = './dataset/FilmTrust/train.txt'
test_data_path = './dataset/FilmTrust/test.txt'
user_emb_path = './embedding/Weight_Egress/XSimGCL_Weight_Egress/FilmTrust/best_user_emb.pt'
item_emb_path = './embedding/Weight_Egress/XSimGCL_Weight_Egress/FilmTrust/best_item_emb.pt'
output_path = '/Users/mean/Downloads/ThinGCN/embedding/Weight_Egress/XSimGCL_Weight_Egress/FilmTrust/XSimGCL_Weight_Egress.png'

# Generate and save the plot
plot_embeddings(train_data_path, test_data_path, user_emb_path, item_emb_path, output_path, title)
