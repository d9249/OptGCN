# %%
import matplotlib.pyplot as plt
from matplotlib import patheffects
import numpy as np

data = {
    "BUIR": {"Weight": None, "Epoch": 291, "Recall@20": 0.83774, "NDCG@20": 0.60724},
    "BUIR_EW": {"Weight": 512, "Epoch": 266, "Recall@20": 0.85103, "NDCG@20": 0.61154},
    "MixGCF": {"Weight": None, "Epoch": 173, "Recall@20": 0.83204, "NDCG@20": 0.61152},
    "MixGCF_EW": {"Weight": 2, "Epoch": 159, "Recall@20": 0.83720, "NDCG@20": 0.62950},
    "LightGCN": {"Weight": None, "Epoch": 276, "Recall@20": 0.85376, "NDCG@20": 0.61566},
    "LightGCN_EW": {"Weight": 4, "Epoch": 216, "Recall@20": 0.86250, "NDCG@20": 0.62011},
    "SGL": {"Weight": None, "Epoch": 121, "Recall@20": 0.85761, "NDCG@20": 0.62903},
    "SGL_W": {"Weight": 2, "Epoch": 86, "Recall@20": 0.86001, "NDCG@20": 0.62691},
    "SimGCL": {"Weight": None, "Epoch": 1, "Recall@20": 0.31356, "NDCG@20": 0.16678},
    "SimGCL_W": {"Weight": 32, "Epoch": 10, "Recall@20": 0.85551, "NDCG@20": 0.63114},
    "XSimGCL": {"Weight": None, "Epoch": 1, "Recall@20": 0.65846, "NDCG@20": 0.48539},
    "XSimGCL_EW": {"Weight": 4, "Epoch": 24, "Recall@20": 0.86259, "NDCG@20": 0.64195},
    "MF": {"Weight": None, "Epoch": 296, "Recall@20": 0.84800, "NDCG@20": 0.61690},
    "SelfCF": {"Weight": None, "Epoch": 7, "Recall@20": 0.04075, "NDCG@20": 0.02646},
    "DirectAU": {"Weight": None, "Epoch": 54, "Recall@20": 0.83840, "NDCG@20": 0.60760},
}




models = list(data.keys())
epochs = [data[model]["Epoch"] for model in models]
recall_at_20 = [data[model]["Recall@20"] for model in models]
ndcg_at_20 = [data[model]["NDCG@20"] for model in models]

filtered_indices = [i for i, (recall, ndcg) in enumerate(zip(recall_at_20, ndcg_at_20)) if recall >= 0.8 and ndcg >= 0.6]

filtered_models = np.array(models)[filtered_indices].tolist()
filtered_recall = np.array(recall_at_20)[filtered_indices].tolist()
filtered_ndcg = np.array(ndcg_at_20)[filtered_indices].tolist()
filtered_epochs = np.array(epochs)[filtered_indices].tolist()

scaled_epochs = [epoch / max(filtered_epochs) * 100 for epoch in filtered_epochs]

plt.figure(figsize=(10, 6))
plt.scatter(filtered_recall, filtered_ndcg, s=scaled_epochs, c=filtered_epochs, cmap='viridis', alpha=0.7)

for i, model in enumerate(filtered_models):
    plt.annotate(model, (filtered_recall[i], filtered_ndcg[i]), textcoords="offset points", xytext=(-7,8), ha='center', fontsize=8)

highlight = "LightGCN_EW"  # Specify the model to highlight

for i, model in enumerate(filtered_models):
    if model == highlight:
        plt.annotate(model, (filtered_recall[i], filtered_ndcg[i]), 
                     textcoords="offset points", xytext=(-7,8), ha='center', fontsize=8,
                     bbox=dict(facecolor='yellow', alpha=0.5))
    else:
        plt.annotate(model, (filtered_recall[i], filtered_ndcg[i]), 
                     textcoords="offset points", xytext=(-7,8), ha='center', fontsize=8)

# Adding labels, title, and colorbar
plt.xlabel("Recall@20")
plt.ylabel("NDCG@20")
plt.title("Recall >= 0.8 and NDCG >= 0.6")
plt.colorbar(label='Epoch')
plt.grid(True)

# Displaying the plot
plt.tight_layout()
plt.savefig('C:\\Users\\admin\\Downloads\\ThinGCN\\docs\\석사 학위\\이미지\\산점도\\FilmTrust_back.png', dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import patheffects
import numpy as np

# Provided data
data = {
    "BUIR": {"Weight": None, "Epoch": 290, "Recall@20": 0.04371, "NDCG@20": 0.03557},
    "BUIR_E": {"Weight": None, "Epoch": 79, "Recall@20": 0.04578, "NDCG@20": 0.03718},
    "MixGCF": {"Weight": None, "Epoch": 96, "Recall@20": 0.07010, "NDCG@20": 0.05752},
    "MixGCF_W": {"Weight": None, "Epoch": 85, "Recall@20": 0.06931, "NDCG@20": 0.05697},
    "LightGCN": {"Weight": None, "Epoch": 231, "Recall@20": 0.05949, "NDCG@20": 0.04887},
    "LightGCN_EW": {"Weight": 8, "Epoch": 36, "Recall@20": 0.06312, "NDCG@20": 0.05148},
    "SGL": {"Weight": None, "Epoch": 27, "Recall@20": 0.06791, "NDCG@20": 0.05585},
    "SGL_W": {"Weight": 2, "Epoch": 23, "Recall@20": 0.06978, "NDCG@20": 0.05716},
    "SimGCL": {"Weight": None, "Epoch": 18, "Recall@20": 0.07248, "NDCG@20": 0.05976},
    "SimGCL_W": {"Weight": 2, "Epoch": 8, "Recall@20": 0.07205, "NDCG@20": 0.05955},
    "XSimGCL": {"Weight": None, "Epoch": 14, "Recall@20": 0.07277, "NDCG@20": 0.06002},
    "XSimGCL_W": {"Weight": 2, "Epoch": 9, "Recall@20": 0.07242, "NDCG@20": 0.05949},
    "MF": {"Weight": None, "Epoch": 101, "Recall@20": 0.04998, "NDCG@20": 0.04055},
    "SelfCF": {"Weight": None, "Epoch": 47, "Recall@20": 0.07017, "NDCG@20": 0.05807},
    "DirectAU": {"Weight": None, "Epoch": 290, "Recall@20": 0.04414, "NDCG@20": 0.03601},
}

models = list(data.keys())
epochs = [data[model]["Epoch"] for model in models]
recall_at_20 = [data[model]["Recall@20"] for model in models]
ndcg_at_20 = [data[model]["NDCG@20"] for model in models]

filtered_indices = [i for i, (recall, ndcg) in enumerate(zip(recall_at_20, ndcg_at_20)) if recall >= 0.066 and ndcg >= 0.03]

filtered_models = np.array(models)[filtered_indices].tolist()
filtered_recall = np.array(recall_at_20)[filtered_indices].tolist()
filtered_ndcg = np.array(ndcg_at_20)[filtered_indices].tolist()
filtered_epochs = np.array(epochs)[filtered_indices].tolist()

scaled_epochs = [epoch / max(filtered_epochs) * 100 for epoch in filtered_epochs]

plt.figure(figsize=(10, 6))
plt.scatter(filtered_recall, filtered_ndcg, s=scaled_epochs, c=filtered_epochs, cmap='viridis', alpha=0.7)

for i, model in enumerate(filtered_models):
    plt.annotate(model, (filtered_recall[i], filtered_ndcg[i]), textcoords="offset points", xytext=(0,8), ha='center', fontsize=8)

# Adding labels, title, and colorbar
plt.xlabel("Recall@20")
plt.ylabel("NDCG@20")
plt.title("Recall >= 0.066 and NDCG >= 0.03")
plt.colorbar(label='Epoch')
plt.grid(True)

# Displaying the plot
plt.tight_layout()
plt.savefig('c:\\Users\\admin\\Downloads\\ThinGCN\\figure\\yelp2018_Updated.png', dpi=1000)
# plt.savefig('/Users/mean/Downloads/ThinGCN/figure/yelp2018_Updated.png', dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import patheffects
import numpy as np

data = {
    "BUIR": {"Weight": None, "Epoch": 298, "Recall@20": 0.19115, "NDCG@20": 0.22593},
    "BUIR_E": {"Weight": None, "Epoch": 299, "Recall@20": 0.20169, "NDCG@20": 0.23589},
    "MixGCF": {"Weight": None, "Epoch": 2, "Recall@20": 0.14913, "NDCG@20": 0.17538},
    "MixGCF_EW": {"Weight": 8, "Epoch": 14, "Recall@20": 0.23060, "NDCG@20": 0.26500},
    "LightGCN": {"Weight": None, "Epoch": 261, "Recall@20": 0.27196, "NDCG@20": 0.30274},
    "LightGCN_EW": {"Weight": 16, "Epoch": 31, "Recall@20": 0.27767, "NDCG@20": 0.31078},
    "SGL": {"Weight": None, "Epoch": 42, "Recall@20": 0.27369, "NDCG@20": 0.30960},
    "SGL_W": {"Weight": 8, "Epoch": 28, "Recall@20": 0.28670, "NDCG@20": 0.32120},
    "SimGCL": {"Weight": None, "Epoch": 217, "Recall@20": 0.25545, "NDCG@20": 0.28191},
    "SimGCL_W": {"Weight": 16, "Epoch": 5, "Recall@20": 0.27620, "NDCG@20": 0.30900},
    "XSimGCL": {"Weight": None, "Epoch": 61, "Recall@20": 0.28515, "NDCG@20": 0.32007},
    "XSimGCL_W": {"Weight": 2, "Epoch": 23, "Recall@20": 0.28430, "NDCG@20": 0.31830},
    "MF": {"Weight": None, "Epoch": 46, "Recall@20": 0.24900, "NDCG@20": 0.28310},
    "SelfCF": {"Weight": None, "Epoch": 8, "Recall@20": 0.10870, "NDCG@20": 0.10300},
    "DirectAU": {"Weight": None, "Epoch": 300, "Recall@20": 0.1924, "NDCG@20": 0.2244},
}

models = list(data.keys())
epochs = [data[model]["Epoch"] for model in models]
recall_at_20 = [data[model]["Recall@20"] for model in models]
ndcg_at_20 = [data[model]["NDCG@20"] for model in models]

filtered_indices = [i for i, (recall, ndcg) in enumerate(zip(recall_at_20, ndcg_at_20)) if recall >= 0.2 and ndcg >= 0.3]

filtered_models = np.array(models)[filtered_indices].tolist()
filtered_recall = np.array(recall_at_20)[filtered_indices].tolist()
filtered_ndcg = np.array(ndcg_at_20)[filtered_indices].tolist()
filtered_epochs = np.array(epochs)[filtered_indices].tolist()

scaled_epochs = [epoch / max(filtered_epochs) * 100 for epoch in filtered_epochs]

plt.figure(figsize=(10, 6))
plt.scatter(filtered_recall, filtered_ndcg, s=scaled_epochs, c=filtered_epochs, cmap='viridis', alpha=0.7)

for i, model in enumerate(filtered_models):
    plt.annotate(model, (filtered_recall[i], filtered_ndcg[i]), textcoords="offset points", xytext=(0,8), ha='center', fontsize=8)

# Adding labels, title, and colorbar
plt.xlabel("Recall@20")
plt.ylabel("NDCG@20")
plt.title("Recall >= 0.2 and NDCG >= 0.3")
plt.colorbar(label='Epoch')
plt.grid(True)

# Displaying the plot
plt.tight_layout()
# plt.savefig('/Users/mean/Downloads/ThinGCN/figure/MovieLens-1m.png', dpi=1000)
plt.savefig('c:\\Users\\admin\\Downloads\\ThinGCN\\figure\\MovieLens-1m_Updated.png', dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import patheffects
import numpy as np

# New provided data
data = {
    "BUIR": {"Weight": None, "Epoch": 298, "Recall@20": 0.08945, "NDCG@20": 0.07097},
    "BUIR_W": {"Weight": 2048, "Epoch": 294, "Recall@20": 0.10467, "NDCG@20": 0.08412},
    "MixGCF": {"Weight": None, "Epoch": 145, "Recall@20": 0.17641, "NDCG@20": 0.16265},
    "MixGCF_W": {"Weight": 2, "Epoch": 133, "Recall@20": 0.17440, "NDCG@20": 0.15820},
    "LightGCN": {"Weight": None, "Epoch": 266, "Recall@20": 0.14783, "NDCG@20": 0.12508},
    "LightGCN_W": {"Weight": 16, "Epoch": 26, "Recall@20": 0.15127, "NDCG@20": 0.12867},
    "SGL": {"Weight": None, "Epoch": 46, "Recall@20": 0.17322, "NDCG@20": 0.15225},
    "SGL_W": {"Weight": 2, "Epoch": 38, "Recall@20": 0.17570, "NDCG@20": 0.15350},
    "SimGCL": {"Weight": None, "Epoch": 51, "Recall@20": 0.16677, "NDCG@20": 0.14781},
    "SimGCL_W": {"Weight": 2, "Epoch": 28, "Recall@20": 0.17041, "NDCG@20": 0.14940},
    "XSimGCL": {"Weight": None, "Epoch": 29, "Recall@20": 0.17632, "NDCG@20": 0.15397},
    "XSimGCL_W": {"Weight": 2, "Epoch": 11, "Recall@20": 0.17709, "NDCG@20": 0.15444},
    "MF": {"Weight": None, "Epoch": 66, "Recall@20": 0.12470, "NDCG@20": 0.10390},
    "SelfCF": {"Weight": None, "Epoch": 23, "Recall@20": 0.13670, "NDCG@20": 0.11890},
    "DirectAU": {"Weight": None, "Epoch": 297, "Recall@20": 0.08509, "NDCG@20": 0.06709},
}

models = list(data.keys())
epochs = [data[model]["Epoch"] for model in models]
recall_at_20 = [data[model]["Recall@20"] for model in models]
ndcg_at_20 = [data[model]["NDCG@20"] for model in models]

filtered_indices = [i for i, (recall, ndcg) in enumerate(zip(recall_at_20, ndcg_at_20)) if recall >= 0.15 and ndcg >= 0.10]

filtered_models = np.array(models)[filtered_indices].tolist()
filtered_recall = np.array(recall_at_20)[filtered_indices].tolist()
filtered_ndcg = np.array(ndcg_at_20)[filtered_indices].tolist()
filtered_epochs = np.array(epochs)[filtered_indices].tolist()

scaled_epochs = [epoch / max(filtered_epochs) * 100 for epoch in filtered_epochs]

plt.figure(figsize=(10, 6))
plt.scatter(filtered_recall, filtered_ndcg, s=scaled_epochs, c=filtered_epochs, cmap='viridis', alpha=0.7)

for i, model in enumerate(filtered_models):
    plt.annotate(model, (filtered_recall[i], filtered_ndcg[i]), textcoords="offset points", xytext=(-2,8), ha='center', fontsize=8)

# Adding labels, title, and colorbar
plt.xlabel("Recall@20")
plt.ylabel("NDCG@20")
plt.title("Recall >= 0.15 and NDCG >= 0.1")
plt.colorbar(label='Epoch')
plt.grid(True)

# Displaying the plot
plt.tight_layout()
# plt.savefig('/Users/mean/Downloads/ThinGCN/figure/douban-book.png', dpi=1000)
plt.savefig('c:\\Users\\admin\\Downloads\\ThinGCN\\figure\\douban-book_Updated.png', dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import patheffects
import numpy as np

data = {
    "BUIR": {"Weight": None, "Epoch": 291, "Recall@20": 0.83774, "NDCG@20": 0.60724},
    "BUIR_EW": {"Weight": 512, "Epoch": 266, "Recall@20": 0.85103, "NDCG@20": 0.61154},
    "MixGCF": {"Weight": None, "Epoch": 173, "Recall@20": 0.83204, "NDCG@20": 0.61152},
    "MixGCF_EW": {"Weight": 2, "Epoch": 159, "Recall@20": 0.83720, "NDCG@20": 0.62950},
    "LightGCN": {"Weight": None, "Epoch": 276, "Recall@20": 0.85376, "NDCG@20": 0.61566},
    "LightGCN_EW": {"Weight": 4, "Epoch": 216, "Recall@20": 0.86250, "NDCG@20": 0.62011},
    "SGL": {"Weight": None, "Epoch": 121, "Recall@20": 0.85761, "NDCG@20": 0.62903},
    "SGL_W": {"Weight": 2, "Epoch": 86, "Recall@20": 0.86001, "NDCG@20": 0.62691},
    "SimGCL": {"Weight": None, "Epoch": 1, "Recall@20": 0.31356, "NDCG@20": 0.16678},
    "SimGCL_W": {"Weight": 32, "Epoch": 10, "Recall@20": 0.85551, "NDCG@20": 0.63114},
    "XSimGCL": {"Weight": None, "Epoch": 1, "Recall@20": 0.65846, "NDCG@20": 0.48539},
    "XSimGCL_EW": {"Weight": 4, "Epoch": 24, "Recall@20": 0.86259, "NDCG@20": 0.64195},
    "MF": {"Weight": None, "Epoch": 296, "Recall@20": 0.84800, "NDCG@20": 0.61690},
    "SelfCF": {"Weight": None, "Epoch": 7, "Recall@20": 0.04075, "NDCG@20": 0.02646},
    "DirectAU": {"Weight": None, "Epoch": 54, "Recall@20": 0.83840, "NDCG@20": 0.60760},
}

models = list(data.keys())
epochs = [data[model]["Epoch"] for model in models]
recall_at_20 = [data[model]["Recall@20"] for model in models]
ndcg_at_20 = [data[model]["NDCG@20"] for model in models]

scaled_epochs = [epoch / max(epochs) * 100 for epoch in epochs]
circle_sizes = [size * 5 for size in scaled_epochs]  # Adjust the multiplier as needed

plt.figure(figsize=(10, 6))
sc = plt.scatter(recall_at_20, ndcg_at_20, s=circle_sizes, c=epochs, cmap='viridis', alpha=0.7)

for i, model in enumerate(models):
    plt.annotate(model, (recall_at_20[i], ndcg_at_20[i]), textcoords="offset points", xytext=(0, 15), ha='center', fontsize=10)  # Increase fontsize as needed

# Adding labels, title, and colorbar
plt.xlabel("Recall@20")
plt.ylabel("NDCG@20")
plt.title("Performance of Models")
plt.colorbar(sc, label='Epoch')
plt.grid(True)

# Displaying the plot
plt.tight_layout()
# plt.show()
plt.savefig('c:\\Users\\admin\\Downloads\\FilmTrust_11.png', dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import patheffects
import numpy as np
from adjustText import adjust_text

# New provided data
data = {
    "BUIR": {"Weight": None, "Epoch": 298, "Recall@20": 0.08945, "NDCG@20": 0.07097},
    "BUIR_W": {"Weight": 2048, "Epoch": 294, "Recall@20": 0.10467, "NDCG@20": 0.08412},
    "MixGCF": {"Weight": None, "Epoch": 145, "Recall@20": 0.17641, "NDCG@20": 0.16265},
    "MixGCF_W": {"Weight": 2, "Epoch": 133, "Recall@20": 0.17440, "NDCG@20": 0.15820},
    "LightGCN": {"Weight": None, "Epoch": 266, "Recall@20": 0.14783, "NDCG@20": 0.12508},
    "LightGCN_W": {"Weight": 16, "Epoch": 26, "Recall@20": 0.15127, "NDCG@20": 0.12867},
    "SGL": {"Weight": None, "Epoch": 46, "Recall@20": 0.17322, "NDCG@20": 0.15225},
    "SGL_W": {"Weight": 2, "Epoch": 38, "Recall@20": 0.17570, "NDCG@20": 0.15350},
    "SimGCL": {"Weight": None, "Epoch": 51, "Recall@20": 0.16677, "NDCG@20": 0.14781},
    "SimGCL_W": {"Weight": 2, "Epoch": 28, "Recall@20": 0.17041, "NDCG@20": 0.14940},
    "XSimGCL": {"Weight": None, "Epoch": 29, "Recall@20": 0.17632, "NDCG@20": 0.15397},
    "XSimGCL_W": {"Weight": 2, "Epoch": 11, "Recall@20": 0.17709, "NDCG@20": 0.15444},
    "MF": {"Weight": None, "Epoch": 66, "Recall@20": 0.12470, "NDCG@20": 0.10390},
    "SelfCF": {"Weight": None, "Epoch": 23, "Recall@20": 0.13670, "NDCG@20": 0.11890},
    "DirectAU": {"Weight": None, "Epoch": 297, "Recall@20": 0.08509, "NDCG@20": 0.06709},
}

models = list(data.keys())
epochs = [data[model]["Epoch"] for model in models]
recall_at_20 = [data[model]["Recall@20"] for model in models]
ndcg_at_20 = [data[model]["NDCG@20"] for model in models]

# Epoch에 따라 원의 크기 조정
scaled_epochs = [epoch / max(epochs) * 100 for epoch in epochs]
circle_sizes = [size * 3 for size in scaled_epochs]  # 원의 크기 조정 계수 변경

plt.figure(figsize=(10, 6))
sc = plt.scatter(recall_at_20, ndcg_at_20, s=circle_sizes, c=epochs, cmap='viridis', alpha=0.7)

texts = []
for i, model in enumerate(models):
    x, y = recall_at_20[i], ndcg_at_20[i]
    texts.append(plt.text(x, y, model, ha='right', va='bottom', fontsize=10))

# 텍스트 라벨의 위치 조정
adjust_text(texts, arrowprops=dict(arrowstyle='-', color='red'))

# 라벨, 제목 및 컬러바 추가
plt.xlabel("Recall@20")
plt.ylabel("NDCG@20")
plt.title("Performance of Models")
plt.colorbar(sc, label='Epoch')
plt.grid(True)

# 플롯 표시
plt.tight_layout()
plt.savefig('c:\\Users\\admin\\Downloads\\douban-book_Updated.png', dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import patheffects
import numpy as np

data = {
    "BUIR": {"Weight": None, "Epoch": 298, "Recall@20": 0.19115, "NDCG@20": 0.22593},
    "BUIR_E": {"Weight": None, "Epoch": 299, "Recall@20": 0.20169, "NDCG@20": 0.23589},
    "MixGCF": {"Weight": None, "Epoch": 2, "Recall@20": 0.14913, "NDCG@20": 0.17538},
    "MixGCF_EW": {"Weight": 8, "Epoch": 14, "Recall@20": 0.23060, "NDCG@20": 0.26500},
    "LightGCN": {"Weight": None, "Epoch": 261, "Recall@20": 0.27196, "NDCG@20": 0.30274},
    "LightGCN_EW": {"Weight": 16, "Epoch": 31, "Recall@20": 0.27767, "NDCG@20": 0.31078},
    "SGL": {"Weight": None, "Epoch": 42, "Recall@20": 0.27369, "NDCG@20": 0.30960},
    "SGL_W": {"Weight": 8, "Epoch": 28, "Recall@20": 0.28670, "NDCG@20": 0.32120},
    "SimGCL": {"Weight": None, "Epoch": 217, "Recall@20": 0.25545, "NDCG@20": 0.28191},
    "SimGCL_W": {"Weight": 16, "Epoch": 5, "Recall@20": 0.27620, "NDCG@20": 0.30900},
    "XSimGCL": {"Weight": None, "Epoch": 61, "Recall@20": 0.28515, "NDCG@20": 0.32007},
    "XSimGCL_W": {"Weight": 2, "Epoch": 23, "Recall@20": 0.28430, "NDCG@20": 0.31830},
    "MF": {"Weight": None, "Epoch": 46, "Recall@20": 0.24900, "NDCG@20": 0.28310},
    "SelfCF": {"Weight": None, "Epoch": 8, "Recall@20": 0.10870, "NDCG@20": 0.10300},
    "DirectAU": {"Weight": None, "Epoch": 300, "Recall@20": 0.1924, "NDCG@20": 0.2244},
}

models = list(data.keys())
epochs = [data[model]["Epoch"] for model in models]
recall_at_20 = [data[model]["Recall@20"] for model in models]
ndcg_at_20 = [data[model]["NDCG@20"] for model in models]

# Epoch에 따라 원의 크기 조정
scaled_epochs = [epoch / max(epochs) * 100 for epoch in epochs]
circle_sizes = [size * 7 for size in scaled_epochs]  # 원의 크기 조정 계수 변경

plt.figure(figsize=(10, 6))
sc = plt.scatter(recall_at_20, ndcg_at_20, s=circle_sizes, c=epochs, cmap='viridis', alpha=0.7)

texts = []
for i, model in enumerate(models):
    x, y = recall_at_20[i], ndcg_at_20[i]
    texts.append(plt.text(x, y, model, ha='right', va='bottom', fontsize=10))

# 텍스트 라벨의 위치 조정
adjust_text(texts, arrowprops=dict(arrowstyle='-', color='red'))

# 라벨, 제목 및 컬러바 추가
plt.xlabel("Recall@20")
plt.ylabel("NDCG@20")
plt.title("Performance of Models")
plt.colorbar(sc, label='Epoch')
plt.grid(True)
plt.savefig('c:\\Users\\admin\\Downloads\\MovieLens-1m_Updated.png', dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from adjustText import adjust_text

# 데이터 로딩
data = {
    "BUIR": {"Weight": None, "Epoch": 290, "Recall@20": 0.04371, "NDCG@20": 0.03557},
    "BUIR_E": {"Weight": None, "Epoch": 79, "Recall@20": 0.04578, "NDCG@20": 0.03718},
    "MixGCF": {"Weight": None, "Epoch": 96, "Recall@20": 0.07010, "NDCG@20": 0.05752},
    "MixGCF_W": {"Weight": None, "Epoch": 85, "Recall@20": 0.06931, "NDCG@20": 0.05697},
    "LightGCN": {"Weight": None, "Epoch": 231, "Recall@20": 0.05949, "NDCG@20": 0.04887},
    "LightGCN_EW": {"Weight": 8, "Epoch": 36, "Recall@20": 0.06312, "NDCG@20": 0.05148},
    "SGL": {"Weight": None, "Epoch": 27, "Recall@20": 0.06791, "NDCG@20": 0.05585},
    "SGL_W": {"Weight": 2, "Epoch": 23, "Recall@20": 0.06978, "NDCG@20": 0.05716},
    "SimGCL": {"Weight": None, "Epoch": 18, "Recall@20": 0.07248, "NDCG@20": 0.05976},
    "SimGCL_W": {"Weight": 2, "Epoch": 8, "Recall@20": 0.07205, "NDCG@20": 0.05955},
    "XSimGCL": {"Weight": None, "Epoch": 14, "Recall@20": 0.07277, "NDCG@20": 0.06002},
    "XSimGCL_W": {"Weight": 2, "Epoch": 9, "Recall@20": 0.07242, "NDCG@20": 0.05949},
    "MF": {"Weight": None, "Epoch": 101, "Recall@20": 0.04998, "NDCG@20": 0.04055},
    "SelfCF": {"Weight": None, "Epoch": 47, "Recall@20": 0.07017, "NDCG@20": 0.05807},
    "DirectAU": {"Weight": None, "Epoch": 290, "Recall@20": 0.04414, "NDCG@20": 0.03601},
}

models = list(data.keys())
epochs = [data[model]["Epoch"] for model in models]
recall_at_20 = [data[model]["Recall@20"] for model in models]
ndcg_at_20 = [data[model]["NDCG@20"] for model in models]

# Epoch에 따라 원의 크기 조정
scaled_epochs = [epoch / max(epochs) * 100 for epoch in epochs]
circle_sizes = [size * 7 for size in scaled_epochs]  # 원의 크기 조정 계수 변경

def annotate_models(ax, models, recall, ndcg, highlighted_models, texts, tmp, 
                    highlight_color='white', highlight_text_color='black', default_text_color='black', 
                    fontsize=10, ha='right', va='bottom'):
    for i, model in enumerate(models):
        x, y = recall[i], ndcg[i]
        if model in highlighted_models:
            # Highlighted models with colored background and different text color
            texts.append(ax.text(x, y, model, ha=ha, va=va, fontsize=fontsize, color=highlight_text_color,
                                 bbox=dict(facecolor=highlight_color, alpha=0.5)))
        else:
            # Regular models without background, added only once with the default text color
            if model not in [text.get_text() for text in texts]:
                tmp.append(ax.text(x, y, model, ha=ha, va=va, fontsize=fontsize, color=default_text_color))

# Usage
plt.figure(figsize=(10, 6))
sc = plt.scatter(recall_at_20, ndcg_at_20, s=circle_sizes, c=epochs, cmap='viridis', alpha=0.7)

texts = []
tmp = []
highlighted_models = ['LightGCN_EW', 'BUIR_E', 'MixGCF_W', 'SGL_W', 'SimGCL_W', 'XSimGCL_W']
ax = plt.gca()  # Get the current Axes instance

# Annotate all models, highlighting specific ones
annotate_models(ax, models, recall_at_20, ndcg_at_20, highlighted_models, texts, tmp, highlight_text_color='red')

# Combine the lists for adjust_text
all_texts = texts + tmp

# Use the adjust_text library to make sure texts do not overlap
adjust_text(all_texts, arrowprops=dict(arrowstyle='-', color='red'))

# Add labels, title, and colorbar
plt.xlabel("Recall@20")
plt.ylabel("NDCG@20")
plt.title("Performance of Models")
plt.colorbar(sc, label='Epoch')
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('c:\\Users\\admin\\Downloads\\yelp2018_Updated.png', dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from adjustText import adjust_text

# 데이터 로딩
data = {
    "BUIR": {"Weight": None, "Epoch": 298, "Recall@20": 0.19115, "NDCG@20": 0.22593},
    "BUIR_E": {"Weight": None, "Epoch": 299, "Recall@20": 0.20169, "NDCG@20": 0.23589},
    "MixGCF": {"Weight": None, "Epoch": 2, "Recall@20": 0.14913, "NDCG@20": 0.17538},
    "MixGCF_EW": {"Weight": 8, "Epoch": 14, "Recall@20": 0.23060, "NDCG@20": 0.26500},
    "LightGCN": {"Weight": None, "Epoch": 261, "Recall@20": 0.27196, "NDCG@20": 0.30274},
    "LightGCN_EW": {"Weight": 16, "Epoch": 31, "Recall@20": 0.27767, "NDCG@20": 0.31078},
    "SGL": {"Weight": None, "Epoch": 42, "Recall@20": 0.27369, "NDCG@20": 0.30960},
    "SGL_W": {"Weight": 8, "Epoch": 28, "Recall@20": 0.28670, "NDCG@20": 0.32120},
    "SimGCL": {"Weight": None, "Epoch": 217, "Recall@20": 0.25545, "NDCG@20": 0.28191},
    "SimGCL_W": {"Weight": 16, "Epoch": 5, "Recall@20": 0.27620, "NDCG@20": 0.30900},
    "XSimGCL": {"Weight": None, "Epoch": 61, "Recall@20": 0.28515, "NDCG@20": 0.32007},
    "XSimGCL_W": {"Weight": 2, "Epoch": 23, "Recall@20": 0.28430, "NDCG@20": 0.31830},
    "MF": {"Weight": None, "Epoch": 46, "Recall@20": 0.24900, "NDCG@20": 0.28310},
    "SelfCF": {"Weight": None, "Epoch": 8, "Recall@20": 0.10870, "NDCG@20": 0.10300},
    "DirectAU": {"Weight": None, "Epoch": 300, "Recall@20": 0.1924, "NDCG@20": 0.2244},
}

models = list(data.keys())
epochs = [data[model]["Epoch"] for model in models]
recall_at_20 = [data[model]["Recall@20"] for model in models]
ndcg_at_20 = [data[model]["NDCG@20"] for model in models]

# Epoch에 따라 원의 크기 조정
scaled_epochs = [epoch / max(epochs) * 100 for epoch in epochs]
circle_sizes = [size * 7 for size in scaled_epochs]  # 원의 크기 조정 계수 변경

def annotate_models(ax, models, recall, ndcg, highlighted_models, texts, tmp, 
                    highlight_color='white', highlight_text_color='black', default_text_color='black', 
                    fontsize=10, ha='right', va='bottom'):
    for i, model in enumerate(models):
        x, y = recall[i], ndcg[i]
        if model in highlighted_models:
            # Highlighted models with colored background and different text color
            texts.append(ax.text(x, y, model, ha=ha, va=va, fontsize=fontsize, color=highlight_text_color,
                                 bbox=dict(facecolor=highlight_color, alpha=0.5)))
        else:
            # Regular models without background, added only once with the default text color
            if model not in [text.get_text() for text in texts]:
                tmp.append(ax.text(x, y, model, ha=ha, va=va, fontsize=fontsize, color=default_text_color))

# Usage
plt.figure(figsize=(10, 6))
sc = plt.scatter(recall_at_20, ndcg_at_20, s=circle_sizes, c=epochs, cmap='viridis', alpha=0.7)

texts = []
tmp = []
highlighted_models = ['BUIR_E', 'MixGCF_EW', 'LightGCN_EW', 'SGL_W', 'SimGCL_W', 'XSimGCL_W']
ax = plt.gca()  # Get the current Axes instance

# Annotate all models, highlighting specific ones
annotate_models(ax, models, recall_at_20, ndcg_at_20, highlighted_models, texts, tmp, highlight_text_color='red')

# Combine the lists for adjust_text
all_texts = texts + tmp

# Use the adjust_text library to make sure texts do not overlap
adjust_text(all_texts, arrowprops=dict(arrowstyle='-', color='red'))

# Add labels, title, and colorbar
plt.xlabel("Recall@20")
plt.ylabel("NDCG@20")
plt.title("Performance of Models")
plt.colorbar(sc, label='Epoch')
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('c:\\Users\\admin\\Downloads\\MovieLens-1m_Updat.png', dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from adjustText import adjust_text

# 데이터 로딩
data = {
    "BUIR": {"Weight": None, "Epoch": 298, "Recall@20": 0.19115, "NDCG@20": 0.22593},
    "BUIR_E": {"Weight": None, "Epoch": 299, "Recall@20": 0.20169, "NDCG@20": 0.23589},
    # "MixGCF": {"Weight": None, "Epoch": 2, "Recall@20": 0.14913, "NDCG@20": 0.17538},
    "MixGCF_EW": {"Weight": 8, "Epoch": 14, "Recall@20": 0.23060, "NDCG@20": 0.26500},
    "LightGCN": {"Weight": None, "Epoch": 261, "Recall@20": 0.27196, "NDCG@20": 0.30274},
    "LightGCN_EW": {"Weight": 16, "Epoch": 31, "Recall@20": 0.27767, "NDCG@20": 0.31078},
    "SGL": {"Weight": None, "Epoch": 42, "Recall@20": 0.27369, "NDCG@20": 0.30960},
    "SGL_W": {"Weight": 8, "Epoch": 28, "Recall@20": 0.28670, "NDCG@20": 0.32120},
    "SimGCL": {"Weight": None, "Epoch": 217, "Recall@20": 0.25545, "NDCG@20": 0.28191},
    "SimGCL_W": {"Weight": 16, "Epoch": 5, "Recall@20": 0.27620, "NDCG@20": 0.30900},
    "XSimGCL": {"Weight": None, "Epoch": 61, "Recall@20": 0.28515, "NDCG@20": 0.32007},
    "XSimGCL_W": {"Weight": 2, "Epoch": 23, "Recall@20": 0.28430, "NDCG@20": 0.31830},
    "MF": {"Weight": None, "Epoch": 46, "Recall@20": 0.24900, "NDCG@20": 0.28310},
    # "SelfCF": {"Weight": None, "Epoch": 8, "Recall@20": 0.10870, "NDCG@20": 0.10300},
    "DirectAU": {"Weight": None, "Epoch": 300, "Recall@20": 0.1924, "NDCG@20": 0.2244},
}

models = list(data.keys())
epochs = [data[model]["Epoch"] for model in models]
recall_at_20 = [data[model]["Recall@20"] for model in models]
ndcg_at_20 = [data[model]["NDCG@20"] for model in models]

# Epoch에 따라 원의 크기 조정
scaled_epochs = [epoch / max(epochs) * 100 for epoch in epochs]
circle_sizes = [size * 7 for size in scaled_epochs]  # 원의 크기 조정 계수 변경

def annotate_models(ax, models, recall, ndcg, highlighted_models, texts, tmp, 
                    highlight_color='white', highlight_text_color='black', default_text_color='black', 
                    fontsize=10, ha='right', va='bottom'):
    for i, model in enumerate(models):
        x, y = recall[i], ndcg[i]
        if model in highlighted_models:
            # Highlighted models with colored background and different text color
            texts.append(ax.text(x, y, model, ha=ha, va=va, fontsize=fontsize, color=highlight_text_color,
                                 bbox=dict(facecolor=highlight_color, alpha=0.5)))
        else:
            # Regular models without background, added only once with the default text color
            if model not in [text.get_text() for text in texts]:
                tmp.append(ax.text(x, y, model, ha=ha, va=va, fontsize=fontsize, color=default_text_color))

# Usage
plt.figure(figsize=(10, 6))
sc = plt.scatter(recall_at_20, ndcg_at_20, s=circle_sizes, c=epochs, cmap='viridis', alpha=0.7)

texts = []
tmp = []
highlighted_models = ['BUIR_E', 'MixGCF_EW', 'LightGCN_EW', 'SGL_W', 'SimGCL_W', 'XSimGCL_W']
ax = plt.gca()  # Get the current Axes instance

# Annotate all models, highlighting specific ones
annotate_models(ax, models, recall_at_20, ndcg_at_20, highlighted_models, texts, tmp, highlight_text_color='red')

# Combine the lists for adjust_text
all_texts = texts + tmp

# Use the adjust_text library to make sure texts do not overlap
adjust_text(all_texts, arrowprops=dict(arrowstyle='-', color='red'))

# Add labels, title, and colorbar
plt.xlabel("Recall@20")
plt.ylabel("NDCG@20")
plt.title("Performance of Models")
plt.colorbar(sc, label='Epoch')
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('c:\\Users\\admin\\Downloads\\MovieLens-1m_Updated.png', dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from adjustText import adjust_text

# 데이터 로딩
data = {
    "BUIR": {"Weight": None, "Epoch": 298, "Recall@20": 0.08945, "NDCG@20": 0.07097},
    "BUIR_W": {"Weight": 2048, "Epoch": 294, "Recall@20": 0.10467, "NDCG@20": 0.08412},
    "MixGCF": {"Weight": None, "Epoch": 145, "Recall@20": 0.17641, "NDCG@20": 0.16265},
    "MixGCF_W": {"Weight": 2, "Epoch": 133, "Recall@20": 0.17440, "NDCG@20": 0.15820},
    "LightGCN": {"Weight": None, "Epoch": 266, "Recall@20": 0.14783, "NDCG@20": 0.12508},
    "LightGCN_W": {"Weight": 16, "Epoch": 26, "Recall@20": 0.15127, "NDCG@20": 0.12867},
    "SGL": {"Weight": None, "Epoch": 46, "Recall@20": 0.17322, "NDCG@20": 0.15225},
    "SGL_W": {"Weight": 2, "Epoch": 38, "Recall@20": 0.17570, "NDCG@20": 0.15350},
    "SimGCL": {"Weight": None, "Epoch": 51, "Recall@20": 0.16677, "NDCG@20": 0.14781},
    "SimGCL_W": {"Weight": 2, "Epoch": 28, "Recall@20": 0.17041, "NDCG@20": 0.14940},
    "XSimGCL": {"Weight": None, "Epoch": 29, "Recall@20": 0.17632, "NDCG@20": 0.15397},
    "XSimGCL_W": {"Weight": 2, "Epoch": 11, "Recall@20": 0.17709, "NDCG@20": 0.15444},
    "MF": {"Weight": None, "Epoch": 66, "Recall@20": 0.12470, "NDCG@20": 0.10390},
    "SelfCF": {"Weight": None, "Epoch": 23, "Recall@20": 0.13670, "NDCG@20": 0.11890},
    "DirectAU": {"Weight": None, "Epoch": 297, "Recall@20": 0.08509, "NDCG@20": 0.06709},
}

models = list(data.keys())
epochs = [data[model]["Epoch"] for model in models]
recall_at_20 = [data[model]["Recall@20"] for model in models]
ndcg_at_20 = [data[model]["NDCG@20"] for model in models]

# Epoch에 따라 원의 크기 조정
scaled_epochs = [epoch / max(epochs) * 100 for epoch in epochs]
circle_sizes = [size * 7 for size in scaled_epochs]  # 원의 크기 조정 계수 변경

def annotate_models(ax, models, recall, ndcg, highlighted_models, texts, tmp, 
                    highlight_color='white', highlight_text_color='black', default_text_color='black', 
                    fontsize=10, ha='right', va='bottom'):
    for i, model in enumerate(models):
        x, y = recall[i], ndcg[i]
        if model in highlighted_models:
            # Highlighted models with colored background and different text color
            texts.append(ax.text(x, y, model, ha=ha, va=va, fontsize=fontsize, color=highlight_text_color,
                                 bbox=dict(facecolor=highlight_color, alpha=0.5)))
        else:
            # Regular models without background, added only once with the default text color
            if model not in [text.get_text() for text in texts]:
                tmp.append(ax.text(x, y, model, ha=ha, va=va, fontsize=fontsize, color=default_text_color))

# Usage
plt.figure(figsize=(10, 6))
sc = plt.scatter(recall_at_20, ndcg_at_20, s=circle_sizes, c=epochs, cmap='viridis', alpha=0.7)

texts = []
tmp = []
highlighted_models = ['BUIR_W', 'MixGCF_W', 'LightGCN_W', 'SGL_W', 'SimGCL_W', 'XSimGCL_W']
ax = plt.gca()  # Get the current Axes instance

# Annotate all models, highlighting specific ones
annotate_models(ax, models, recall_at_20, ndcg_at_20, highlighted_models, texts, tmp, highlight_text_color='red')

# Combine the lists for adjust_text
all_texts = texts + tmp

# Use the adjust_text library to make sure texts do not overlap
adjust_text(all_texts, arrowprops=dict(arrowstyle='-', color='red'))

# Add labels, title, and colorbar
plt.xlabel("Recall@20")
plt.ylabel("NDCG@20")
plt.title("Performance of Models")
plt.colorbar(sc, label='Epoch')
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('c:\\Users\\admin\\Downloads\\douban-book_Updated.png', dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from adjustText import adjust_text

# 데이터 로딩
data = {
    "BUIR": {"Weight": None, "Epoch": 291, "Recall@20": 0.83774, "NDCG@20": 0.60724},
    "BUIR_EW": {"Weight": 512, "Epoch": 266, "Recall@20": 0.85103, "NDCG@20": 0.61154},
    "MixGCF": {"Weight": None, "Epoch": 173, "Recall@20": 0.83204, "NDCG@20": 0.61152},
    "MixGCF_EW": {"Weight": 2, "Epoch": 159, "Recall@20": 0.83720, "NDCG@20": 0.62950},
    "LightGCN": {"Weight": None, "Epoch": 276, "Recall@20": 0.85376, "NDCG@20": 0.61566},
    "LightGCN_EW": {"Weight": 4, "Epoch": 161, "Recall@20": 0.86316, "NDCG@20": 0.61970},
    "SGL": {"Weight": None, "Epoch": 121, "Recall@20": 0.85761, "NDCG@20": 0.62903},
    "SGL_W": {"Weight": 2, "Epoch": 86, "Recall@20": 0.86001, "NDCG@20": 0.62691},
    "SimGCL": {"Weight": None, "Epoch": 1, "Recall@20": 0.31356, "NDCG@20": 0.16678},
    "SimGCL_W": {"Weight": 32, "Epoch": 10, "Recall@20": 0.85551, "NDCG@20": 0.63114},
    "XSimGCL": {"Weight": None, "Epoch": 1, "Recall@20": 0.65846, "NDCG@20": 0.48539},
    "XSimGCL_EW": {"Weight": 4, "Epoch": 24, "Recall@20": 0.86259, "NDCG@20": 0.64195},
    "MF": {"Weight": None, "Epoch": 296, "Recall@20": 0.84800, "NDCG@20": 0.61690},
    "SelfCF": {"Weight": None, "Epoch": 7, "Recall@20": 0.04075, "NDCG@20": 0.02646},
    "DirectAU": {"Weight": None, "Epoch": 54, "Recall@20": 0.83840, "NDCG@20": 0.60760},
}

models = list(data.keys())
epochs = [data[model]["Epoch"] for model in models]
recall_at_20 = [data[model]["Recall@20"] for model in models]
ndcg_at_20 = [data[model]["NDCG@20"] for model in models]

# Epoch에 따라 원의 크기 조정
scaled_epochs = [epoch / max(epochs) * 100 for epoch in epochs]
circle_sizes = [size * 7 for size in scaled_epochs]  # 원의 크기 조정 계수 변경

def annotate_models(ax, models, recall, ndcg, highlighted_models, texts, tmp, 
                    highlight_color='white', highlight_text_color='black', default_text_color='black', 
                    fontsize=10, ha='right', va='bottom'):
    for i, model in enumerate(models):
        x, y = recall[i], ndcg[i]
        if model in highlighted_models:
            # Highlighted models with colored background and different text color
            texts.append(ax.text(x, y, model, ha=ha, va=va, fontsize=fontsize, color=highlight_text_color,
                                 bbox=dict(facecolor=highlight_color, alpha=0.5)))
        else:
            # Regular models without background, added only once with the default text color
            if model not in [text.get_text() for text in texts]:
                tmp.append(ax.text(x, y, model, ha=ha, va=va, fontsize=fontsize, color=default_text_color))

# Usage
plt.figure(figsize=(10, 6))
sc = plt.scatter(recall_at_20, ndcg_at_20, s=circle_sizes, c=epochs, cmap='viridis', alpha=0.7)

texts = []
tmp = []
highlighted_models = ['BUIR_EW', 'MixGCF_EW', 'LightGCN_EW', 'SGL_W', 'SimGCL_W', 'XSimGCL_EW']
ax = plt.gca()  # Get the current Axes instance

# Annotate all models, highlighting specific ones
annotate_models(ax, models, recall_at_20, ndcg_at_20, highlighted_models, texts, tmp, highlight_text_color='red')

# Combine the lists for adjust_text
all_texts = texts + tmp

# Use the adjust_text library to make sure texts do not overlap
adjust_text(all_texts, arrowprops=dict(arrowstyle='-', color='red'))

# Add labels, title, and colorbar
plt.xlabel("Recall@20")
plt.ylabel("NDCG@20")
plt.title("Performance of Models")
plt.colorbar(sc, label='Epoch')
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('c:\\Users\\admin\\Downloads\\FilmTrust_Updated.png', dpi=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from adjustText import adjust_text

# 데이터 로딩
data = {
    "BUIR": {"Weight": None, "Epoch": 291, "Recall@20": 0.83774, "NDCG@20": 0.60724},
    "BUIR_EW": {"Weight": 512, "Epoch": 266, "Recall@20": 0.85103, "NDCG@20": 0.61154},
    "MixGCF": {"Weight": None, "Epoch": 173, "Recall@20": 0.83204, "NDCG@20": 0.61152},
    "MixGCF_EW": {"Weight": 2, "Epoch": 159, "Recall@20": 0.83720, "NDCG@20": 0.62950},
    "LightGCN": {"Weight": None, "Epoch": 276, "Recall@20": 0.85376, "NDCG@20": 0.61566},
    "LightGCN_EW": {"Weight": 4, "Epoch": 161, "Recall@20": 0.86316, "NDCG@20": 0.61970},
    "SGL": {"Weight": None, "Epoch": 121, "Recall@20": 0.85761, "NDCG@20": 0.62903},
    "SGL_W": {"Weight": 2, "Epoch": 86, "Recall@20": 0.86001, "NDCG@20": 0.62691},
    # "SimGCL": {"Weight": None, "Epoch": 1, "Recall@20": 0.31356, "NDCG@20": 0.16678},
    "SimGCL_W": {"Weight": 32, "Epoch": 10, "Recall@20": 0.85551, "NDCG@20": 0.63114},
    # "XSimGCL": {"Weight": None, "Epoch": 1, "Recall@20": 0.65846, "NDCG@20": 0.48539},
    "XSimGCL_EW": {"Weight": 4, "Epoch": 24, "Recall@20": 0.86259, "NDCG@20": 0.64195},
    "MF": {"Weight": None, "Epoch": 296, "Recall@20": 0.84800, "NDCG@20": 0.61690},
    # "SelfCF": {"Weight": None, "Epoch": 7, "Recall@20": 0.04075, "NDCG@20": 0.02646},
    "DirectAU": {"Weight": None, "Epoch": 54, "Recall@20": 0.83840, "NDCG@20": 0.60760},
}

models = list(data.keys())
epochs = [data[model]["Epoch"] for model in models]
recall_at_20 = [data[model]["Recall@20"] for model in models]
ndcg_at_20 = [data[model]["NDCG@20"] for model in models]

# Epoch에 따라 원의 크기 조정
scaled_epochs = [epoch / max(epochs) * 100 for epoch in epochs]
circle_sizes = [size * 7 for size in scaled_epochs]  # 원의 크기 조정 계수 변경

def annotate_models(ax, models, recall, ndcg, highlighted_models, texts, tmp, 
                    highlight_color='white', highlight_text_color='black', default_text_color='black', 
                    fontsize=10, ha='right', va='bottom'):
    for i, model in enumerate(models):
        x, y = recall[i], ndcg[i]
        if model in highlighted_models:
            # Highlighted models with colored background and different text color
            texts.append(ax.text(x, y, model, ha=ha, va=va, fontsize=fontsize, color=highlight_text_color,
                                 bbox=dict(facecolor=highlight_color, alpha=0.5)))
        else:
            # Regular models without background, added only once with the default text color
            if model not in [text.get_text() for text in texts]:
                tmp.append(ax.text(x, y, model, ha=ha, va=va, fontsize=fontsize, color=default_text_color))

# Usage
plt.figure(figsize=(10, 6))
sc = plt.scatter(recall_at_20, ndcg_at_20, s=circle_sizes, c=epochs, cmap='viridis', alpha=0.7)

texts = []
tmp = []
highlighted_models = ['BUIR_EW', 'MixGCF_EW', 'LightGCN_EW', 'SGL_W', 'SimGCL_W', 'XSimGCL_EW']
ax = plt.gca()  # Get the current Axes instance

# Annotate all models, highlighting specific ones
annotate_models(ax, models, recall_at_20, ndcg_at_20, highlighted_models, texts, tmp, highlight_text_color='red')

# Combine the lists for adjust_text
all_texts = texts + tmp

# Use the adjust_text library to make sure texts do not overlap
adjust_text(all_texts, arrowprops=dict(arrowstyle='-', color='red'))

# Add labels, title, and colorbar
plt.xlabel("Recall@20")
plt.ylabel("NDCG@20")
plt.title("Performance of Models")
plt.colorbar(sc, label='Epoch')
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('c:\\Users\\admin\\Downloads\\FilmTrust_Updat.png', dpi=1000)
plt.show()
